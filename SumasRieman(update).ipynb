# %% [markdown]
# <a href="https://colab.research.google.com/github/davichomendez1901-byte/Simulaci-n-Remix/blob/main/SumasRieman(update).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt


def riemannplot(f, a, b, ra, rb, n):
    # f es la función
    # a y b son los limites del eje x para graficar la funcion f
    # ra y rb son los limites del intervalo en el eje x del que queremos calcular la suma
    # n es el numero de rectangulos que calcularemos

    atenuacion = (b-a)/100
    x = np.arange(a, b+atenuacion, atenuacion)

    plt.plot(x, f(x), color='red')

    delta_x = (rb-ra)/n
    riemannx = np.arange(ra, rb, delta_x)
    riemanny = f(riemannx)
    riemann_sum = sum(riemanny*delta_x)

    plt.bar(riemannx,riemanny,width=delta_x,alpha=0.5,edgecolor = 'black',facecolor='green')

    plt.xlabel('x')
    plt.ylabel('f(x)')

    plt.title('Suma de Riemann por la izquierda de f(x)')
    plt.figtext(0.1,-0.05, "Suma de Riemann: %.5f " %(riemann_sum), color='b')
    plt.savefig('riemann.png')
    plt.show()

# %%
def f(x):
    return np.sqrt(np.arctan(x))

# %%
riemannplot(f, 0, 1.001, 0, 1.001, 20)

# %%
def intGrandesNum(f, n):
    x = np.random.rand(n)
#    np.sort(x)
    g = f(x)
#    suma = np.sum(g)

    arriteraciones = np.arange(n)
    arrint = np.empty((0,n))
    suma = 0
    for i in x:
        suma+= f(i)
        arrint = np.concatenate( ( arrint, suma/n) , axis=None)

    plt.figure(num=None, figsize=(10, 12), dpi=80, facecolor='w', edgecolor='k')
    plt.yscale("logit")
    plt.scatter(arriteraciones, arrint, marker='.', alpha=0.1, color ='red', cmap='viridis')
    plt.tight_layout()
    plt.xlabel('Número de iteraciones')
    plt.ylabel('Valor de la integral')
    plt.savefig('valorIntegralIteraciones.png')



    integral = suma/n
    print ('integral por ley de grandes numeros: %.5f' %(integral))
    #histograma
    #g = f(x)
    #plt.hist(g, bins=20, edgecolor = 'black',facecolor='green')
    #plt.xlabel('g(x)')
    #plt.ylabel('Frecuencia')
    #plt.title('Valores de la función en 1000 iteraciones')
    #plt.savefig('g(x).png')

    plt.show()

intGrandesNum(f, 1000)
# Out:
# /tmp/ipykernel_2148/203847558.py:16: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(arriteraciones, arrint, marker='.', alpha=0.1, color ='red', cmap='viridis')
# integral por ley de grandes numeros: 0.63284
